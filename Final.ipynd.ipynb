# %%
import final as fn
from final import solve_odes
import matplotlib.pyplot as plt
plt.xkcd()
import warnings
warnings.filterwarnings('ignore')

# %%
sol = solve_odes(2, T = 500, dt = 0.001, a = 0.2, b = 0.2)

# %%
fn.plotx(sol)

# %%
fn.ploty(sol)

# %%
fn.plotz(sol)

# %%
fn.plotxy(sol, S=100, T=500)

# %%
fn.plotzy(sol, S=100, T=500)

# %%
fn.plotzx(sol, S=100, T=500)

# %%
fn.plotxyz(sol, S=100, T=500)

# %% [markdown]
# Using the value c = 3

# %%
sol = solve_odes(3, T = 500, dt = 0.001, a = 0.2, b = 0.2)

# %%
fn.plotx(sol)

# %% [markdown]
# This one compared to the first (with value c=2) has a bit more variation in its oscillations. The first one had its starting out oscillations which are growing and then got into a stable motion where it was oscillating between 2 points. This one added a bit more to the sequence and oscillated between 4 different points each time it went throgh the sequence

# %%
fn.plotxy(sol, S=100, T=500)

# %% [markdown]
# This too had a bit more than the first one (with value c=2), instead of 1 circle, it added in an extra little swirl to its motion

# %%
fn.plotxyz(sol, S=100, T=500)

# %% [markdown]
# This motion got longer and wider than in the first one, other than that, not too much of a change. We can see the motion and its movements a bit better than before since it is wider.

# %% [markdown]
# using the value c = 4

# %%
sol = solve_odes(4, T = 500, dt = 0.001, a = 0.2, b = 0.2)

# %%
fn.plotx(sol)

# %% [markdown]
# Here we added another couple oscillations to the sequence, it looks like there are 4 seperate oscillations in each round of the sequence now, as opposed to 2 when the value of c=3. It is getting a bit more particular

# %%
fn.plotxy(sol, S=100, T=500)

# %% [markdown]
# Here we see another fuller line added to the entire loop. Instead of just the one loop with the added spin in it, there are now two seperate loops going through this entire motion together. How fun! He made a friend

# %%
fn.plotxyz(sol, S=100, T=500)

# %% [markdown]
# Here the lines are starting to blend together a bit and make large lines, where the little ones were before. It makes it alot easier to see the motion of this plot, it seems as though the motion is getting more constant and specific here

# %% [markdown]
# Using the value c =4.15

# %%
sol = solve_odes(4.15, T = 500, dt = 0.001, a = 0.2, b = 0.2)

# %%
fn.plotx(sol)

# %% [markdown]
# Even more variation in the sequence, yay! This one the lines are getting to higher and lower points for the big oscillations and the smaller oscillations are staying even closer to the zero value!

# %%
fn.plotxy(sol, S=100, T=500)

# %% [markdown]
# I think they made a few more friends, but I cant tell because they all blended together....

# %%
fn.plotxyz(sol, S=100, T=500)

# %% [markdown]
# This one is pretty exciting, it goes up and then swirls down into the same plot we have above (x-y) as it approaches the ground of the plot. The orbit on the ground is very constant and I love to see that

# %% [markdown]
# Using the value c = 4.2

# %%
sol = solve_odes(4.2, T = 500, dt = 0.001, a = 0.2, b = 0.2)

# %%
fn.plotx(sol)

# %%
fn.plotxy(sol, S=100, T=500)

# %%
fn.plotxyz(sol, S=100, T=500)

# %% [markdown]
# Using the value c = 5.7

# %%
sol = solve_odes(5.7, T = 500, dt = 0.001, a = 0.2, b = 0.2)

# %%
fn.plotx(sol)

# %% [markdown]
# Comparing this to the midterm, I noticed that it was very similar to our plot (the difference being that this one is cuter). Though this one starts at a value close to zero and then grows, where as the midterm one starts close to zero then ramps up to a higher number and stays around there. I noticed that when we increase the value of c the plot seems to get more accurate (I believe), it is showing a larger variation of steps in the sequence, where as when the c value was smaller the oscillations seemed to be about the same height everytime.

# %%
fn.plotxy(sol, S=100, T=500)

# %% [markdown]
# For this plot we see a big swirl, which I also enjoy looking at. This one is by far my favorite of the plots :) In this plot we see as the c value increases the number of lines in the swirl increases. We start with just one line (when c value is 2) and then when we change the c value to 3 there are 2 swirls and it increases from there until we are at this one, which has an uncountable number of swirls! Looks kinda like a black hole honestly

# %%
fn.plotxyz(sol, S=100, T=500)

# %% [markdown]
# The specific motion is a little difficult to see here since all the lines have blended together. Though we can see that it swirls around the x, y axis and then goes up the z axis in another swirl before coming back down. The motion on the x, y axis looks very similar to the plot directly above (as it should because that one is the x-y plot).

# %%
xmax = fn.findmaxima(sol, S = 100)
fn.scatter(xmax, dc = .01, dt= .001)

# %% [markdown]
# This scatter plot took slightly over 2 hours to run, but the results were super interesting. It gave a plot very similar to our midterm plot. It looks a bit like the scream from a side view, I would flip it to show you, but alas I do not have those skills :(, maybe if we were in a different realm where I had the skills and time to do so. This sequence was shown after the first 100 iterations of the sequence. The numbers begin to converge pretty quickly together when the c value is low, though as it gets larger the points vary more. At the beginning of this plot the points converge into a couple seperate lines better quickly, but as the c value grows it begins to seperate and vary throughout a bigger range of x values.I still dont know why those gaps are there, I wanna know. Please do explain this cause I'm confused.
